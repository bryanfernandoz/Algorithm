# %% [markdown]
# # Polar Contour Plot

# %% [markdown]
# # import library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Generate r and theta arrays

# %%
rad_arr=np.radians(np.linspace(0,360,20))
r_arr=np.arange(0,1,.1)

# %% [markdown]
# # Define Function

# %%
def func(r,theta):
  return r*np.sin(theta)

# %%
r,theta=np.meshgrid(r_arr,rad_arr)

# %% [markdown]
# # Get the values of response variables

# %%
values=func(r,theta)

# %% [markdown]
# # Plot the polar coordinates

# %%
fig,ax=plt.subplots(subplot_kw=dict(projection='polar'))
ax.contourf(theta,r,values,cmp='Spectral_r')
plt.show()
# Out:
# <ipython-input-11-27f0cb0ad245>:2: UserWarning: The following kwargs were not used by contour: 'cmp'
#   ax.contourf(theta,r,values,cmp='Spectral_r')
